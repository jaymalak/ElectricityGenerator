# %% [markdown]
# <a href="https://colab.research.google.com/github/jaymalak/ElectricityGenerator/blob/master/MAY2014.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Import Package

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import pie, axis, show
# %matplotlib inline                                                              

import warnings                                                                 # Ignore warning related to pandas_profiling
warnings.filterwarnings('ignore') 
pd.set_option('display.max_columns', 100)                                       # Display all dataframe columns in outputs 
import glob
import io

# %% [markdown]
# Loading Data

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a33f4ff0-f0f6-41c6-85b9-89233dc59ece" name="files[]" multiple disabled />
#      <output id="result-a33f4ff0-f0f6-41c6-85b9-89233dc59ece">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Reasonmaster_may14.xls to Reasonmaster_may14 (1).xls

# %%
reasonmst = pd.read_excel(io.BytesIO(uploaded['Reasonmaster_may14.xls']))

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-5654db12-0b27-44cb-9190-c556b50c4b8b" name="files[]" multiple disabled />
#      <output id="result-5654db12-0b27-44cb-9190-c556b50c4b8b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving technicalminload.xls to technicalminload.xls

# %%
techminload = pd.read_excel(io.BytesIO(uploaded['technicalminload.xls']))

# %%
reasonmst.head()
# Out:
#        DATE             STATIONAME  REVISION NO.  \
# 0  1\5\2014  INTRASTATE_BILATERAL              1
# 1  1\5\2014           REL_THERMAL              2
# 2  1\5\2014            CHANDRAPUR              3
# 3  1\5\2014                 PARAS              4
# 4  1\5\2014              BHUSAWAL              5
#
#                                               REASON                TIME
# 0  INTRASTATE_BILATERAL -JSW REV1 AND VIPL U2& DH... 2014-05-01 11:22:39
# 1               REL_THERMAL -FOR SMOOTHENING BY SLDC 2014-05-01 11:33:21
# 2  CHANDRAPUR -U3,4 BUNKERING PROB ,U5&7 PCQ U6 R... 2014-05-01 12:03:21
# 3                   PARAS -PCQ: BLK 1-96: 460-431 MW 2014-05-01 12:13:05
# 4               BHUSAWAL -U4 ASH SERIES PROB &U5 PCQ 2014-05-01 12:33:17

# %%
techminload.head()
# Out:
#            Station Unit No.  MCR Capacity  \
# 0              NaN      NaN           NaN
# 1              NaN      NaN           NaN
# 2  MSPGCL BHUSAWAL      2 *         210.0
# 3  MSPGCL BHUSAWAL        3         210.0
# 4  MSPGCL BHUSAWAL      4 #         500.0
#
#    Technical Minimum load    for  Scheduling     Type
# 0                                         NaN     NaN
# 1                                         NaN     NaN
# 2                                      143.89  MSPGCL
# 3                                      143.89  MSPGCL
# 4                                      322.00  MSPGCL

# %%
reasonmst.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1622 entries, 0 to 1621
# Data columns (total 5 columns):
# DATE            1622 non-null object
# STATIONAME      1622 non-null object
# REVISION NO.    1622 non-null int64
# REASON          1622 non-null object
# TIME            1622 non-null datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 63.5+ KB

# %%
techminload.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 5 columns):
# Station                                       60 non-null object
# Unit No.                                      60 non-null object
# MCR Capacity                                  60 non-null float64
# Technical Minimum load    for  Scheduling     60 non-null float64
# Type                                          60 non-null object
# dtypes: float64(2), object(3)
# memory usage: 2.5+ KB

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f28d7976-88de-4712-96e6-34199665a4af" name="files[]" multiple disabled />
#      <output id="result-f28d7976-88de-4712-96e6-34199665a4af">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving MSPGCL_UNT_WISE_01_May_2014_47.xls to MSPGCL_UNT_WISE_01_May_2014_47.xls

# %%
may1 = pd.read_excel(io.BytesIO(uploaded['MSPGCL_UNT_WISE_01_May_2014_47.xls']))

# %%
may1.head()
# Out:
#    BLOCK NO  KORADI_U1  KORADI_U2  KORADI_U3  KORADI_U4  KORADI_U5  KORADI_U6  \
# 0         1          0          0          0          0          0        144
# 1         2          0          0          0          0          0        144
# 2         3          0          0          0          0          0        144
# 3         4          0          0          0          0          0        144
# 4         5          0          0          0          0          0        144
#
#    KORADI_U7  KORADI  NASIK_U1  NASIK_U2  NASIK_U3  NASIK_U4  NASIK_U5  \
# 0        144     288         0         0   172.000   172.000   172.000
# 1        144     288         0         0   172.000   146.847   172.000
# 2        144     288         0         0   172.000   142.000   164.054
# 3        144     288         0         0   166.762   142.000   141.000
# 4        144     288         0         0   172.000   142.000   167.602
#
# ...

# %% [markdown]
# Two duplicate columns found in May1 DataFrame

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-46925c40-fdfc-4916-a5fc-edc2665f9cfe" name="files[]" multiple disabled />
#      <output id="result-46925c40-fdfc-4916-a5fc-edc2665f9cfe">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving colname.xls to colname (2).xls

# %%
colname = pd.read_excel(io.BytesIO(uploaded['colname.xls']))

# %%
colname.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75 entries, 0 to 74
# Data columns (total 2 columns):
# Sno            75 non-null int64
# Column_name    75 non-null object
# dtypes: int64(1), object(1)
# memory usage: 1.3+ KB

# %%
from google.colab import files
import numpy as np
import pandas as pd
import glob

uploaded = files.upload()

##files.upload returns a dictionary of the files which were uploaded. The 
##dictionary is keyed by the file name, the value is the data which was 
##uploaded.
i = 1
all_data = pd.DataFrame()
all_data['mdate'] =[]
for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(name=fn, length=len(uploaded[fn])))
  df = pd.read_excel(fn)
  df['mdate'] = i
  i = i + 1
  all_data = all_data.append(df,ignore_index=True)

# %%
df.head()

# %%
all_data.head()

# %%
all_data.info()

# %%
reason_search = reasonmst[reasonmst['REASON'].str.contains('SLDC',case=False) ] 
reason_search
# Out:
#            DATE             STATIONAME  REVISION NO.  \
# 0      1\5\2014  INTRASTATE_BILATERAL              1
# 1      1\5\2014           REL_THERMAL              2
# 5      1\5\2014                 NASIK              6
# 6      1\5\2014            CHANDRAPUR              7
# 8      1\5\2014           KHAPERKHEDA              9
# ...         ...                    ...           ...
# 1585  31\5\2014                 NASIK              2
# 1586  31\5\2014           KHAPERKHEDA              3
# 1587  31\5\2014            CHANDRAPUR              4
# 1591  31\5\2014               TPCL_U5              8
# 1601  31\5\2014                  VIPL             18
#
#                                                  REASON                TIME
# 0     INTRASTATE_BILATERAL -JSW REV1 AND VIPL U2& DH... 2014-05-01 11:22:39
# 1                  REL_THERMAL -FOR SMOOTHENING BY SLDC 2014-05-01 11:33:21
# 5                     NASIK -BACKBOWN BY SLDC BLK 53-58 2014-05-01 12:41:49
# ...

# %%
reasonmst['TYPE']='NONSLDC'
reasonmst.loc[reasonmst['REASON'].str.contains('SLDC',case=False), 'TYPE'] = 'SLDC'
reasonmst.head()
# Out:
#        DATE             STATIONAME  REVISION NO.  \
# 0  1\5\2014  INTRASTATE_BILATERAL              1
# 1  1\5\2014           REL_THERMAL              2
# 2  1\5\2014            CHANDRAPUR              3
# 3  1\5\2014                 PARAS              4
# 4  1\5\2014              BHUSAWAL              5
#
#                                               REASON                TIME  \
# 0  INTRASTATE_BILATERAL -JSW REV1 AND VIPL U2& DH... 2014-05-01 11:22:39
# 1               REL_THERMAL -FOR SMOOTHENING BY SLDC 2014-05-01 11:33:21
# 2  CHANDRAPUR -U3,4 BUNKERING PROB ,U5&7 PCQ U6 R... 2014-05-01 12:03:21
# 3                   PARAS -PCQ: BLK 1-96: 460-431 MW 2014-05-01 12:13:05
# 4               BHUSAWAL -U4 ASH SERIES PROB &U5 PCQ 2014-05-01 12:33:17
#
#       TYPE
# 0     SLDC
# 1     SLDC
# 2  NONSLDC
# 3  NONSLDC
# 4  NONSLDC

# %%
gdate = all_data.groupby('mdate')
gdate.first()
gdate.get_group(1.0)
gdate.unique()

# %%
def trim_all_columns(df):
    """
    Trim whitespace from ends of each value across all series in dataframe
    """
    trim_strings = lambda x: x.strip() if isinstance(x, str) else x
    return df.applymap(trim_strings)


# simple example of trimming whitespace from data elements
reasonmst = trim_all_columns(reasonmst)
reasonmst
# Out:
#            DATE            STATIONAME  REVISION NO.  \
# 0      1\5\2014  INTRASTATE_BILATERAL             1
# 1      1\5\2014           REL_THERMAL             2
# 2      1\5\2014            CHANDRAPUR             3
# 3      1\5\2014                 PARAS             4
# 4      1\5\2014              BHUSAWAL             5
# ...         ...                   ...           ...
# 1617  31\5\2014              BEST_DEM            34
# 1618  31\5\2014              RELD_DEM            35
# 1619  31\5\2014              TPCD_DEM            36
# 1620  31\5\2014            MSEDCL_DEM            37
# 1621  31\5\2014            MSEDCL_DEM            38
#
#                                                  REASON                TIME  \
# 0     INTRASTATE_BILATERAL -JSW REV1 AND VIPL U2& DH... 2014-05-01 11:22:39
# 1                  REL_THERMAL -FOR SMOOTHENING BY SLDC 2014-05-01 11:33:21
# 2     CHANDRAPUR -U3,4 BUNKERING PROB ,U5&7 PCQ U6 R... 2014-05-01 12:03:21
# ...

# %% [markdown]
# #Search Columns which have more than one Unique Values

# %%
col_with_moreval=[]
for col in may1.columns:
   ## if may1[col].dtype =='O':
        if len(may1[col].unique()) >1:
           col_with_moreval.append(may1[col].name)
           
        else:
            continue
col_with_moreval
df=pd.DataFrame(col_with_moreval,columns=['matchval'])     ##Convert List to DataFrame
df
# Out:
#             matchval
# 0           BLOCK NO
# 1           NASIK_U3
# 2           NASIK_U4
# 3           NASIK_U5
# 4              NASIK
# 5        BHUSAWAL_U4
# 6        BHUSAWAL_U5
# 7           BHUSAWAL
# 8      CHANDRAPUR_U1
# 9      CHANDRAPUR_U2
# 10     CHANDRAPUR_U3
# 11     CHANDRAPUR_U4
# 12     CHANDRAPUR_U5
# 13     CHANDRAPUR_U6
# 14     CHANDRAPUR_U7
# 15        CHANDRAPUR
# 16          PARAS_U3
# 17          PARAS_U4
# 18             PARAS
# 19    KHAPERKHEDA_U1
# 20    KHAPERKHEDA_U2
# 21    KHAPERKHEDA_U4
# 22    KHAPERKHEDA_U5
# 23       KHAPERKHEDA
# 24         PARALI_U5
# 25         PARALI_U6
# 26         PARALI_U7
# 27            PARALI
# 28        MSEDCL_THA
# 29        URAN_STG_2
# 30         URAN_WHRP
# 31              URAN
# 32        MSEDCL_GAS
# 33        GHATGHAR_1
# 34        GHATGHAR_2
# 35          GHATGHAR
# 36          KOYNA_IV
# 37        KOYNA_I_II
# 38   KOYNA_STG_1_2_4
# 39         KOYNA_III
# 40          BHATGHAR
# 41          PENCH_MS
# ...

# %%
station_merge = pd.merge(reasonmst, df, how='inner', left_on='STATIONAME', right_on='matchval')
station_merge.head()
# Out:
#        DATE  STATIONAME  REVISION NO.  \
# 0  1\5\2014  CHANDRAPUR             3
# 1  1\5\2014  CHANDRAPUR             7
# 2  1\5\2014  CHANDRAPUR            21
# 3  1\5\2014  CHANDRAPUR            22
# 4  2\5\2014  CHANDRAPUR             5
#
#                                               REASON                TIME  \
# 0  CHANDRAPUR -U3,4 BUNKERING PROB ,U5&7 PCQ U6 R... 2014-05-01 12:03:21
# 1             CHANDRAPUR -BACKDOWN BY SLDC BLK 36-48 2014-05-01 12:53:00
# 2                 CHANDRAPUR -Rev 2 blk 65 to 96 ICQ 2014-08-20 13:22:35
# 3  CHANDRAPUR -Rev 3 blk 67 to 96 ICQ and BD by S... 2014-08-20 16:53:19
# 4   CHANDRAPUR -5CHANDRAPURBD WD BLK 9 TO 28 BY SLDC 2014-05-02 02:31:12
#
#       TYPE    matchval
# 0  NONSLDC  CHANDRAPUR
# 1     SLDC  CHANDRAPUR
# 2  NONSLDC  CHANDRAPUR
# 3     SLDC  CHANDRAPUR
# 4     SLDC  CHANDRAPUR

# %%
TY_NONSLDC.info()
TY_NONSLDC["DATE"]= pd.to_datetime(TY_NONSLDC["DATE"]) 
#TY_NONSLDC.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 436 entries, 0 to 632
# Data columns (total 7 columns):
# DATE            436 non-null object
# STATIONAME      436 non-null object
# REVISION NO.    436 non-null int64
# REASON          436 non-null object
# TIME            436 non-null datetime64[ns]
# TYPE            436 non-null object
# matchval        436 non-null object
# dtypes: datetime64[ns](1), int64(1), object(5)
# memory usage: 27.2+ KB
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/core/arrays/datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    1978         try:
# -> 1979             values, tz_parsed = conversion.datetime_to_datetime64(data)
#    1980             # If tzaware, these values represent unix timestamps, so we
#
# ...

# %%
TY_NONSLDC = station_merge[pd.to_datetime('DATE', format='%d-%m-%y')] == date(1,5,2014)
TY_NONSLDC.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/core/tools/datetimes.py in _convert_listlike_datetimes(arg, box, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     447             try:
# --> 448                 values, tz = conversion.datetime_to_datetime64(arg)
#     449                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#
# pandas/_libs/tslibs/conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-228-a20296b19fb7> in <module>()
# ----> 1 TY_NONSLDC = station_merge[pd.to_datetime('DATE', format='%d-%m-%y')] == date(1,5,2014)
# ...

# %%
##colname.loc[colname['Column_name']].str.contains([reasonmst.STATIONAME],case=False)
##reasonmst.loc[reasonmst['STATIONAME']].str.contains(colname.Column_name,case=False)
may1.iloc[0:96,1:2]
# Out:
#     KORADI_U1
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ..        ...
# 91          0
# 92          0
# 93          0
# 94          0
# 95          0
#
# [96 rows x 1 columns]

# %%
x=np.where(colname['Column_name'].isin(reasonmst['STATIONAME']))
df = pd.DataFrame(x[0],columns=['test'])
df
# Out:
#     test
# 0      8
# 1     14
# 2     20
# 3     28
# 4     32
# 5     38
# 6     46
# 7     51
# 8     53
# 9     56
# 10    59
# 11    61
# 12    69
# 13    70
# 14    71

# %%
coln = ["BLOCK NO","NASIK","CHANDRAPUR","KORADI_U1","BHUSAWAL"]
for (row, col) in reasonmst.iterrows():
    if col.STATIONAME in coln:
      ##if pd.datetime(col.DATE) == ('1\5\2014'):
           print(col.DATE,col.STATIONAME,col.TYPE)
# Out:
# 1\5\2014 CHANDRAPUR NONSLDC
# 1\5\2014 BHUSAWAL NONSLDC
# 1\5\2014 NASIK SLDC
# 1\5\2014 CHANDRAPUR SLDC
# 1\5\2014 BHUSAWAL NONSLDC
# 1\5\2014 CHANDRAPUR NONSLDC
# 1\5\2014 CHANDRAPUR SLDC
# 1\5\2014 BHUSAWAL NONSLDC
# 1\5\2014 BHUSAWAL SLDC
# 2\5\2014 BHUSAWAL SLDC
# 2\5\2014 CHANDRAPUR SLDC
# 2\5\2014 CHANDRAPUR NONSLDC
# 2\5\2014 BHUSAWAL NONSLDC
# 2\5\2014 CHANDRAPUR NONSLDC
# 2\5\2014 BHUSAWAL NONSLDC
# 2\5\2014 CHANDRAPUR SLDC
# 2\5\2014 BHUSAWAL SLDC
# 2\5\2014 NASIK SLDC
# 3\5\2014 CHANDRAPUR NONSLDC
# 3\5\2014 BHUSAWAL SLDC
# 3\5\2014 BHUSAWAL NONSLDC
# 3\5\2014 CHANDRAPUR NONSLDC
# 3\5\2014 NASIK SLDC
# 3\5\2014 BHUSAWAL SLDC
# 3\5\2014 BHUSAWAL NONSLDC
# 4\5\2014 NASIK SLDC
# 4\5\2014 BHUSAWAL SLDC
# 4\5\2014 CHANDRAPUR NONSLDC
# 4\5\2014 CHANDRAPUR NONSLDC
# 4\5\2014 BHUSAWAL NONSLDC
# 4\5\2014 CHANDRAPUR NONSLDC
# 4\5\2014 NASIK NONSLDC
# 5\5\2014 NASIK NONSLDC
# 5\5\2014 CHANDRAPUR NONSLDC
# 5\5\2014 BHUSAWAL NONSLDC
# 5\5\2014 BHUSAWAL NONSLDC
# ...
